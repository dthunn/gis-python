# %%
from shapely.geometry import Point, LineString, Polygon, MultiPoint, MultiLineString, MultiPolygon, CAP_STYLE
from helpers import *

# %%
point1 = Point(1, 1)
point2 = Point(-50, 60)
line1 = LineString([(0, 0), (2, 2)])
line2 = LineString([(-1, 2), (5, 2)])
poly1 = Polygon([(0, 0), (4, 0), (4, 4), (0, 4), (0, 0)])
poly2 = Polygon([(-3, -2), (6, 4), (-3, 2), (3, 4), (-3, -2)])

# %%
pnt_buffer = point1.buffer(3)

plot_geometries(point1, point1.buffer(3))

# %%
point1.buffer(3, resolution = 1)
# Out:
# <POLYGON ((4 1, 1 -2, -2 1, 1 4, 4 1))>

# %%
buffer1 = line1.buffer(.2)
buffer1
# Out:
# <POLYGON ((1.859 2.141, 1.873 2.155, 1.889 2.166, 1.906 2.176, 1.923 2.185, ...>

# %%
buffer2 = line1.buffer(.2, cap_style = CAP_STYLE.flat)
buffer2
# Out:
# <POLYGON ((1.859 2.141, 2.141 1.859, 0.141 -0.141, -0.141 0.141, 1.859 2.141))>

# %%
plot_three_geometries(line1, buffer1, buffer2)

# %%
line = LineString([(0,0), (1, 0.2), (2, -.1), (3, 5), (4, 6)])

# %%
simple_line1 = line.simplify(1)
simple_line2 = line.simplify(.5)

# %%
plot_geometries(line, simple_line2)

# %%
points = MultiPoint([(1,1), (2,4), (4,2)])
points
# Out:
# <MULTIPOINT ((1 1), (2 4), (4 2))>

# %%
points.envelope
# Out:
# <POLYGON ((1 1, 4 1, 4 4, 1 4, 1 1))>

# %%
plot_geometries(points, points.envelope)

# %%
lines = MultiLineString([line1, line2])
lines
# Out:
# <MULTILINESTRING ((0 0, 2 2), (-1 2, 5 2))>

# %%
plot_geometries(lines, lines.envelope)

# %%
points.convex_hull
# Out:
# <POLYGON ((1 1, 2 4, 4 2, 1 1))>

# %%
plot_three_geometries(points, points.envelope, points.convex_hull)
